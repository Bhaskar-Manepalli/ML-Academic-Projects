# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Attribute Selection
import pandas as pd

df=pd.read_csv('/content/drive/MyDrive/Iris (2).csv')
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
df1=df.select_dtypes(include=[float,int]).corr()
print(df1)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
df2 = df.drop(columns=['Id','SepalLengthCm'])
print(df2.shape)
# Out:
# (150, 4)

# %%
#Handling Missing Values
df3=df.isnull()
print(df3.sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import numpy as np
df.loc[1,'SepalLengthCm']=np.nan
df.loc[2,'PetalLengthCm']=np.nan
df.loc[3,'SepalLengthCm']=np.nan
df.loc[4,'PetalWidthCm']=np.nan

print(df.isna().sum())
# Out:
# Id               0
# SepalLengthCm    2
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     1
# Species          0
# dtype: int64

# %%
print(df.head())
print(df.tail())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# ...

# %%
df4=df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean())
print(df4.isnull().sum())
print(df4.head())
# Out:
# 0
# 0    5.100000
# 1    5.858108
# 2    4.700000
# 3    5.858108
# 4    5.000000
# Name: SepalLengthCm, dtype: float64

# %%
# Discretization
dff=pd.read_csv('/content/drive/MyDrive/Iris (2).csv')

dff['SepalLength_Category']=pd.cut(
    dff['SepalLengthCm'],
    bins=[0,5,10,15],
    labels=['Low','Medium','High']
)
print(dff[['SepalLengthCm','SepalLength_Category']].head(20))
# Out:
#     SepalLengthCm SepalLength_Category
# 0             5.1               Medium
# 1             4.9                  Low
# 2             4.7                  Low
# 3             4.6                  Low
# 4             5.0                  Low
# 5             5.4               Medium
# 6             4.6                  Low
# 7             5.0                  Low
# 8             4.4                  Low
# 9             4.9                  Low
# 10            5.4               Medium
# 11            4.8                  Low
# 12            4.8                  Low
# 13            4.3                  Low
# 14            5.8               Medium
# 15            5.7               Medium
# 16            5.4               Medium
# 17            5.1               Medium
# 18            5.7               Medium
# 19            5.1               Medium

# %%
dff['PetalWidthCm_Category']=pd.cut(
    dff['PetalWidthCm'],
    bins=[0,1,2,3],
    labels=['Low','Medium','High']
)
print(dff[['PetalWidthCm','PetalWidthCm_Category']].tail(20))k
# Out:
#      PetalWidthCm PetalWidthCm_Category
# 130           1.9                Medium
# 131           2.0                Medium
# 132           2.2                  High
# 133           1.5                Medium
# 134           1.4                Medium
# 135           2.3                  High
# 136           2.4                  High
# 137           1.8                Medium
# 138           1.8                Medium
# 139           2.1                  High
# 140           2.4                  High
# 141           2.3                  High
# 142           1.9                Medium
# 143           2.3                  High
# 144           2.5                  High
# 145           2.3                  High
# 146           1.9                Medium
# 147           2.0                Medium
# 148           2.3                  High
# 149           1.8                Medium

# %%
#Handling Outliers
df=pd.read_csv('/content/drive/MyDrive/Iris (2).csv')
column='SepalLengthCm'

Q1=df[column].quantile(0.25)
Q3=df[column].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Q1 =",Q1)
print("Q3 =",Q3)
print("IQR =",IQR)
print("Lower Bound =",lower_bound)
print("Upper Bound =",upper_bound)
outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
print("Outliers:")
print(outliers)
# Out:
# Q1 = 5.1
# Q3 = 6.4
# IQR = 1.3000000000000007
# Lower Bound = 3.1499999999999986
# Upper Bound = 8.350000000000001
# Outliers:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []
